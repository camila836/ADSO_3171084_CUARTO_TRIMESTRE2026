# %%
#VAmos a aplicar de la forma tradicional
#Encapsulamiento y validaciones seguras a los atributos de la clase libro
class Libro:
  def __init__(self, titulo, precio):
    self.__titulo = titulo
    self.__precio = precio

  #GETTER = Consulta, ve, muestra; accede al valor almacenado en el atributo

  def get_titulo(self):
    #vamos a devolver el valor almacenado en titulo
    return self.__titulo

  def get_precio(self):
    return self.__precio

  #SETTER modifica los valores, controla y los valida
  def set_titulo(self, titulo):
    if isinstance(nuevo_titulo, str):
      self.__titulo = nuevo_titulo
    else:
      print("Debe ingresar un titulo valido \n")

  def set_precio(self, nuevo_precio):
    if isinstance(nuevo_precio, (int, float)) and nuevo_precio >= 0:
      self.__precio = nuevo_precio
    else:
      print("Debe ingresar un valor válido \n")

  def mostrar_info(self):
    print(f"Titulo: (self.__titulo)")
    print(f"Precio $(self.__precio:,.2f)")

  def main():
      print("\n=== Sistema de Libros ADSO ===")

      libro1 = Libro("Danganronpa Zero", 220000)

      print("Informacion principal del libro\n")
      libro1.mostrar_info

      print("Precio actual del libro\n")
      print(f"Precio actual: ", libro1.get_precio())

      libro1.set_precio("hola")
      libro1.set_precio("212000")
      print(f"El nuevo precio actualizado es: ", libro1.get_precio())

      print("Información principal del libro\n")
      libro1.mostrar_info()
  if __name__ == "__main__":
      main()
# Out:
# === Sistema de Libros ADSO ===
# Informacion principal del libro
#
# Precio actual del libro
#
# Precio actual:  220000
# Debe ingresar un valor válido
#
# Debe ingresar un valor válido
#
# El nuevo precio actualizado es:  220000
# Información principal del libro
#
# Titulo: (self.__titulo)
# Precio $(self.__precio:,.2f)
